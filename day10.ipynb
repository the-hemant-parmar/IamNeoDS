# %% [markdown]
# # Seaborn and advanced plotting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Linear model plot (lmplot)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
days = ['Monday','Tuesday','Wednesday','Thurday','Friday','Saturday','Sunday']
tempratures = [22,24,20,26,25,27,23]

data = pd.DataFrame({"Days": days, "Temperature": tempratures})

plt.figure(figsize=[10,5])
sns.lineplot(data=data, x='Days', y='Temperature', marker='o', ax=ax1, color='orange', linewidth=3)
plt.figure(figsize=[10, 6])
plt.plot(days, tempratures, linestyle="-")
plt.title("Temprature data for a week")
plt.xlabel("Days")
plt.ylabel("Tempratures")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=[10,6])
plt.plot(days, tempratures, linestyle = '-')
plt.title("Temprature data for a week")
plt.xlabel("Days")
plt.ylabel("Tempratures")
plt.grid(True)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (10,10))

ax1.plot(days, tempratures, linestyle='-', color='orange', linewidth=3, marker='s', markersize=8)
ax1.set_title("Temprature data for a week")
ax1.set_xlabel("Days")
ax1.set_ylabel("Tempratures")
ax1.grid(True)

ax2.bar(days, tempratures, color='lightblue')
ax2.set_title("Temprature data daily comparison", fontsize=18)
ax2.set_xlabel("Days")
ax2.set_ylabel("Tempratures")
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (10,10))

ax1.plot(days, tempratures, linestyle='-', color='orange', linewidth=3, marker='s', markersize=8)
ax1.set_title("Temprature data for a week")
ax1.set_xlabel("Days")
ax1.set_ylabel("Tempratures")
ax1.grid(True)

ax2.bar(days, tempratures, color='lightblue')
ax2.set_title("Temprature data daily comparison", fontsize=18)
ax2.set_xlabel("Days")
ax2.set_ylabel("Tempratures")
ax2.grid(True)

# plt.tight_layout()
plt.show()
