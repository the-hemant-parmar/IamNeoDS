# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
# from sklearn.tree import plot_tree

# %%
data = pd.read_csv('data/weather_classification_data.csv')
data.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0         14.0        73         9.5               82.0  partly cloudy
# 1         39.0        96         8.5               71.0  partly cloudy
# 2         30.0        64         7.0               16.0          clear
# 3         38.0        83         1.5               82.0          clear
# 4         27.0        74        17.0               66.0       overcast
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2  Winter              3.5    inland
# 1               1011.43         7  Spring             10.0    inland
# 2               1018.72         5  Spring              5.5  mountain
# 3               1026.25         7  Spring              1.0   coastal
# 4                990.67         1  Winter              2.5  mountain
#
#   Weather Type
# 0        Rainy
# 1       Cloudy
# 2        Sunny
# 3        Sunny
# 4        Rainy

# %%
data.describe()
# Out:
#         Temperature      Humidity    Wind Speed  Precipitation (%)  \
# count  13200.000000  13200.000000  13200.000000       13200.000000
# mean      19.127576     68.710833      9.832197          53.644394
# std       17.386327     20.194248      6.908704          31.946541
# min      -25.000000     20.000000      0.000000           0.000000
# 25%        4.000000     57.000000      5.000000          19.000000
# 50%       21.000000     70.000000      9.000000          58.000000
# 75%       31.000000     84.000000     13.500000          82.000000
# max      109.000000    109.000000     48.500000         109.000000
#
#        Atmospheric Pressure      UV Index  Visibility (km)
# count          13200.000000  13200.000000     13200.000000
# mean            1005.827896      4.005758         5.462917
# std               37.199589      3.856600         3.371499
# min              800.120000      0.000000         0.000000
# 25%              994.800000      1.000000         3.000000
# 50%             1007.650000      3.000000         5.000000
# 75%             1016.772500      7.000000         7.500000
# max             1199.210000     14.000000        20.000000

# %%
encoder = LabelEncoder()
for col in ['Cloud Cover','Season','Location','Weather Type']:
    data[f'Encoded {col}'] = encoder.fit_transform(data[col])
data.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0         14.0        73         9.5               82.0  partly cloudy
# 1         39.0        96         8.5               71.0  partly cloudy
# 2         30.0        64         7.0               16.0          clear
# 3         38.0        83         1.5               82.0          clear
# 4         27.0        74        17.0               66.0       overcast
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2  Winter              3.5    inland
# 1               1011.43         7  Spring             10.0    inland
# 2               1018.72         5  Spring              5.5  mountain
# 3               1026.25         7  Spring              1.0   coastal
# 4                990.67         1  Winter              2.5  mountain
#
#   Weather Type  Encoded Cloud Cover  Encoded Season  Encoded Location  \
# 0        Rainy                    3               3                 1
# 1       Cloudy                    3               1                 1
# 2        Sunny                    0               1                 2
# 3        Sunny                    0               1                 0
# 4        Rainy                    2               3                 2
#
#    Encoded Weather Type
# 0                     1
# 1                     0
# 2                     3
# 3                     3
# 4                     1

# %%
numerical_data = data.drop(labels=["Cloud Cover", "Season", "Location", "Weather Type"], axis = 1)
numerical_data.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)  Atmospheric Pressure  \
# 0         14.0        73         9.5               82.0               1010.82
# 1         39.0        96         8.5               71.0               1011.43
# 2         30.0        64         7.0               16.0               1018.72
# 3         38.0        83         1.5               82.0               1026.25
# 4         27.0        74        17.0               66.0                990.67
#
#    UV Index  Visibility (km)  Encoded Cloud Cover  Encoded Season  \
# 0         2              3.5                    3               3
# 1         7             10.0                    3               1
# 2         5              5.5                    0               1
# 3         7              1.0                    0               1
# 4         1              2.5                    2               3
#
#    Encoded Location  Encoded Weather Type
# 0                 1                     1
# 1                 1                     0
# 2                 2                     3
# 3                 0                     3
# 4                 2                     1

# %%
# numerical_data.drop_duplicates()

# %%
X = numerical_data.drop(["Encoded Weather Type"],axis = 1)
y = numerical_data["Encoded Weather Type"]
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
print(X_train.head(), X_test.head())
# Out:
#       Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 3958         32.0        66         6.0               92.0
# 2239         15.0        96        11.0               57.0
# 3608         28.0        58         6.5               11.0
# 6848         47.0        84        44.5               85.0
# 6119         18.0        66        14.0               10.0
#
#       Atmospheric Pressure  UV Index  Visibility (km)  Encoded Cloud Cover  \
# 3958               1010.21         2              1.5                    3
# 2239               1016.98         0              4.0                    2
# 3608               1025.37        10              9.0                    0
# 6848                992.26         2              2.0                    2
# 6119               1000.04         1              8.0                    3
#
#       Encoded Season  Encoded Location
# 3958               1                 1
# 2239               0                 2
# 3608               2                 1
# 6848               3                 0
# 6119               0                 0          Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 4111          23.0        38         4.5                6.0
# 10607         62.0        94        14.5               83.0
# 7372          40.0        51         2.0               12.0
# 11786         -7.0        79         6.5               90.0
# 12227         21.0        94        10.0              109.0
#
#        Atmospheric Pressure  UV Index  Visibility (km)  Encoded Cloud Cover  \
# 4111                1021.19         9             10.0                    0
# 10607               1025.57        10              4.0                    0
# 7372                1025.15         8              8.0                    3
# 11786                993.56         0              1.5                    2
# 12227               1027.71        11              9.0                    3
#
#        Encoded Season  Encoded Location
# 4111                0                 1
# 10607               2                 1
# 7372                1                 2
# 11786               3                 1
# 12227               1                 2

# %%
numerical_data.shape
# Out:
# (13200, 11)

# %%
X_train.shape, X_test.shape
# Out:
# ((10560, 10), (2640, 10))

# %%
classifier = RandomForestClassifier(n_estimators=50, random_state=41)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=41)

# %%
y_pred = classifier.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9102272727272728

# %%
# plt.figure(figsize=(10,8))
# plot_tree(classifier)
# plt.show()
